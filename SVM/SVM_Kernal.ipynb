# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load data
df = pd.read_csv("mysvmkernel.csv")
df.head()
# Out:
#    Unnamed: 0        X1       X2  Y
# 0           0  8.660254 -5.00000  0
# 1           1  8.717792 -4.89899  0
# 2           2  8.773790 -4.79798  0
# 3           3  8.828277 -4.69697  0
# 4           4  8.881281 -4.59596  0

# %%
# drop extra column
df.drop("Unnamed: 0", axis = 1, inplace = True)
df.head()
# Out:
#          X1       X2  Y
# 0  8.660254 -5.00000  0
# 1  8.717792 -4.89899  0
# 2  8.773790 -4.79798  0
# 3  8.828277 -4.69697  0
# 4  8.881281 -4.59596  0

# %%
# check for null values
df.isnull().sum()
# Out:
# X1    0
# X2    0
# Y     0
# dtype: int64

# %%
# plot a scatter chart
plt.scatter(df.X1, df.X2)
plt.show()

# %%
# split data into dependent and independent variables
x = df[["X1", "X2"]]
y = df.Y

# %%
x.head()
# Out:
#          X1       X2
# 0  8.660254 -5.00000
# 1  8.717792 -4.89899
# 2  8.773790 -4.79798
# 3  8.828277 -4.69697
# 4  8.881281 -4.59596

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Y, dtype: int64

# %%
# import train test split
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y, test_size = 0.2)

# %%
len(train_x), len(test_x), len(train_y), len(test_y)
# Out:
# (320, 80, 320, 80)

# %%
# import support vector classifier
from sklearn.svm import SVC

# %%
# create object
model = SVC(kernel="rbf")

# %%
# pass values to train model
model.fit(train_x, train_y)
# Out:
# SVC()

# %%
# check efficiency
model.score(test_x, test_y)
# Out:
# 1.0

# %%
df.head()
# Out:
#          X1       X2  Y
# 0  8.660254 -5.00000  0
# 1  8.717792 -4.89899  0
# 2  8.773790 -4.79798  0
# 3  8.828277 -4.69697  0
# 4  8.881281 -4.59596  0

# %%
# create columns for plotting 
df["X1**2"] = df.X1**2
df["X2**2"] = df.X2**2
# z axis
df["X1*X2"] = df.X1*df.X2

# %%
df.head()
# Out:
#          X1       X2  Y      X1**2      X2**2      X1*X2
# 0  8.660254 -5.00000  0  75.000000  25.000000 -43.301270
# 1  8.717792 -4.89899  0  75.999898  24.000102 -42.708375
# 2  8.773790 -4.79798  0  76.979390  23.020610 -42.096467
# 3  8.828277 -4.69697  0  77.938476  22.061524 -41.466150
# 4  8.881281 -4.59596  0  78.877155  21.122845 -40.818009

# %%
# import plotly express
import plotly.express as px

# %%
# In this plot, we can see that we are not able to differentiate the data using a single line
px.scatter_3d(df, x = "X1", y = "X2", z = "X1*X2", color = "Y")

# %%
# In this plot, we can see that we are able to differentiate the data using a single line
px.scatter_3d(df, x = "X1**2", y = "X2**2", z = "X1*X2", color = "Y")
